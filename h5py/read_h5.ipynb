# %%
import h5py

# %%
import os
os.getcwd()
# Out:
# 'C:\\Workspace\\edwa0468\\GitHubs\\EdwardsLab\\h5py'

# %%
h5file = 'tmp.h5'
f = h5py.File(h5file, 'r')

# %%
list(f.keys())
# Out:
# ['contigs']

# %%
list(f['contigs'].keys())
# Out:
# ['*',
#  'contig_1',
#  'contig_10',
#  'contig_100',
#  'contig_1001',
#  'contig_1002',
#  'contig_1003',
#  'contig_1005',
#  'contig_1006',
#  'contig_1007',
#  'contig_1008',
#  'contig_1009',
#  'contig_101',
#  'contig_1011',
#  'contig_1012',
#  'contig_1013',
#  'contig_1014',
#  'contig_1016',
#  'contig_1017',
#  'contig_1018',
#  'contig_102',
#  'contig_1021',
#  'contig_1022',
#  'contig_1023',
#  'contig_1024',
#  'contig_1025',
#  'contig_1026',
#  'contig_1027',
#  'contig_1028',
#  'contig_1029',
#  'contig_103',
#  'contig_1030',
#  'contig_1031',
#  'contig_1032',
#  'contig_1033',
#  'contig_1034',
#  'contig_1035',
#  'contig_1037',
#  'contig_1038',
#  'contig_1039',
#  'contig_104',
#  'contig_1040',
#  'contig_1041',
#  'contig_1043',
#  'contig_1044',
#  'contig_1045',
#  'contig_1046',
#  'contig_1047',
#  'contig_1048',
#  'contig_1049',
#  'contig_1050',
#  'contig_1051',
#  'contig_1052',
#  'contig_1053',
#  'contig_1057',
#  'contig_1058',
# ...

# %%
dset=f['contigs']['contig_1085']

# %%
dset[:]
# Out:
# array([   123, 673234], dtype=int64)
